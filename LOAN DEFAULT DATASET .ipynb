# %%
import pandas as pd
pd.read_csv("Loan_Default.csv")
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
loan=pd.read_csv("Loan_Default.csv")

# %%
loan
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
loan.dtypes
# Out:
# ID                             int64
# year                           int64
# loan_limit                    object
# Gender                        object
# approv_in_adv                 object
# loan_type                     object
# loan_purpose                  object
# Credit_Worthiness             object
# open_credit                   object
# business_or_commercial        object
# loan_amount                    int64
# rate_of_interest             float64
# Interest_rate_spread         float64
# Upfront_charges              float64
# term                         float64
# Neg_ammortization             object
# interest_only                 object
# lump_sum_payment              object
# property_value               float64
# construction_type             object
# occupancy_type                object
# Secured_by                    object
# total_units                   object
# income                       float64
# credit_type                   object
# ...

# %%
#check for empty cells
loan.isnull().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
#to fill
loan.fillna(0)
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
loan=loan.fillna(0)

# %%
loan
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
#to count to see how many gende
loan["Gender"].value_counts()
# Out:
# Male                 42346
# Joint                41399
# Sex Not Available    37659
# Female               27266
# Name: Gender, dtype: int64

# %%
#checking for duplicates
loan.duplicated().sum()
# Out:
# 0

# %%
loan["Gender"].isnull().sum()
# Out:
# 0

# %%
#number of unique
loan["Region"].value_counts()
# Out:
# North         74722
# south         64016
# central        8697
# North-East     1235
# Name: Region, dtype: int64

# %% [markdown]
# ## converting categorical to numerical

# %%
#NORTH-O,SOUTH-1,CENTRAL-2,NORTH EAST-3
loan["Region"].map({"North":0,"south":1,"central":2,"North-East":3})
# Out:
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 148665    1
# 148666    1
# 148667    0
# 148668    0
# 148669    0
# Name: Region, Length: 148670, dtype: int64

# %%
loan["Region"]=loan["Region"].map({"North":0,"south":1,"central":2,"North-East":3})

# %%
loan
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
#to view all the columns
pd.set_option("display.max_columns",None)

# %%
loan
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
loan["loan_type"].value_counts()
# Out:
# type1    113173
# type2     20762
# type3     14735
# Name: loan_type, dtype: int64

# %%
#to convert the loan to 0,1,2
loan["loan_type"].map({"type1":0,"type2":1,"type3":2})
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: loan_type, Length: 148670, dtype: int64

# %%
loan["loan_type"]=loan["loan_type"].map({"type1":0,"type2":1,"type3":2})

# %%
#region,loan_type,

x=loan[["Region","loan_type","rate_of_interest","loan_amount","property_value","income"]]
y=loan["Status"]

# %%
from sklearn.model_selection import train_test_split

# %%
#to split x,y
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
#assign to model
model=LogisticRegression()

# %%
#to fit
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#to predict
model.predict(x_train)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.predict(x_test)
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
import warnings
warnings.filterwarnings("ignore")
model.predict([[1,2,4.8,120000,400000,1500]])
# Out:
# array([0], dtype=int64)

# %%
#to check the correlation
#if its closer to 1 its is strongly correlated
#if its negative is not
#u will use positive 0 as ur x and 1 as your y
loan.corr()["Status"]
# Out:
# ID                      0.001703
# year                         NaN
# loan_type               0.052301
# loan_amount            -0.036825
# rate_of_interest       -0.958875
# Interest_rate_spread   -0.392977
# Upfront_charges        -0.431183
# term                   -0.000675
# property_value         -0.273267
# income                 -0.044620
# Credit_Score            0.004004
# LTV                    -0.267700
# Region                  0.048387
# Status                  1.000000
# dtir1                  -0.325613
# Name: Status, dtype: float64
